# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["size"].unique()    # for show unique values
# Out:
# array([2, 3, 4, 1, 6, 5], dtype=int64)

# %%
tips["size"].nunique()    # number of unique values
# Out:
# 6

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="day", style="smoker", size="tip")

# %%
import numpy as np
import pandas as pd

df = pd.DataFrame(np.random.randn(100, 2), columns=["a", "b"])

# %%
df.head()
# Out:
#           a         b
# 0  0.562209 -1.621626
# 1  0.971884  2.023638
# 2  0.731808  1.405878
# 3 -0.137054 -0.310781
# 4  1.940716  0.237308

# %%
sns.relplot(data=df, x="a", y="b", kind="line")

# %%
sns.relplot(data=tips, x="day", y="total_bill")

# %%
sns.catplot(data=tips, x="day", y="total_bill", hue="sex", kind="swarm")

# %%
sns.catplot(data=tips, x="day", y="tip", kind="swarm")
# Out:
# c:\Users\milan\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3399: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=tips, x="smoker", y="tip", kind="box", hue="smoker")

# %%
sns.catplot(data=tips, x="smoker", y="tip", kind="violin", hue="smoker")

# %%
sns.catplot(data=tips, x="smoker", y="tip", kind="point")

# %%
sns.catplot(data=tips, x="day", y="tip", kind="point")

# %%
sns.distplot(tips["total_bill"])
# Out:
# C:\Users\milan\AppData\Local\Temp\ipykernel_21048\1984207902.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["total_bill"])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips["size"])
# Out:
# C:\Users\milan\AppData\Local\Temp\ipykernel_21048\3388720557.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips["size"])
# <Axes: xlabel='size', ylabel='Density'>

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(data=iris, hue="species")

# %%
sns.regplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
Day = tips[tips["day"]=="Sun"]
Day
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3
# 190       15.69  1.50    Male    Yes  Sun  Dinner     2
#
# [76 rows x 7 columns]

# %%
sns.jointplot(data=Day, x="total_bill", y="tip")

# %%
sns.jointplot(data=tips, x="total_bill", y="tip", kind="hex")

# %%
sns.jointplot(data=tips, x="total_bill", y="tip", kind="kde")

# %%
sns.jointplot(data=tips, x="total_bill", y="tip", kind="reg")
