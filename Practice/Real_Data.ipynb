# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("cleaned.csv")
df.head()
# Out:
#     Brand                                Product_Description  Screen_Size RAM  \
# 0  Lenovo  Lenovo ThinkPad 14” HD Laptop PC Computer Core...         14.0  16
# 1    Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6  64
# 2      HP  NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...         15.6   8
# 3  Lenovo  2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...         15.6  Up
# 4  Lenovo  2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...         15.6  16
#
#                  Processor                     GPU  \
# 0   Intel Core i5 7th Gen.   Intel HD Graphics 520
# 1   Intel Core i5 8th Gen.  Intel UHD Graphics 620
# 2  Intel Core i5 11th Gen.  Intel Iris Xe Graphics
# 3  Intel Core i5 11th Gen.  Intel Iris Xe Graphics
# 4  Intel Core i5 11th Gen.  Intel Iris Xe Graphics
#
#                        GPU_Type   Resolution                Condition   Price
# 0  Integrated/On-Board Graphics          NaN  Very Good - Refurbished  189.99
# ...

# %%
df.sort_values('Price', ascending=True)
# Out:
#          Brand                                Product_Description  \
# 1729     Razer  Razer Blade 16" (1TB SSD, Intel Core i9 13th G...
# 1369      Dell  Dell XPS 15 9530 15.6" (1TB SSD, Intel Core i9...
# 2287        HP  HP Envy x360 15-ed0003ca 15.6" (1TB SSD, Intel...
# 948       Dell  Dell Latitude Rugged 7330 32GB I7 512GB 4G LTE...
# 2698      Dell  2021 Dell Latitude 7320 Detachable i7-1180G7 1...
# ...        ...                                                ...
# 2668  Gigabyte  Aorus 13.9" X3 Plus v5 Intel Core i7 6700HQ (2...
# 2247      Dell  Dell Latitude 7430 i7-1265U 2TB PCIe 16GB FHD ...
# 220     Lenovo  Lenovo ThinkPad X1 Carbon Gen 11 14 2023 FHD+ ...
# 2454      Dell  Dell Precision 7550 Laptop i7-10875H 512GB PCI...
# 2313      Dell  Dell Gaming G15 5510 15.6" 512GB SSD Core i7-1...
#
#       Screen_Size RAM                Processor                            GPU  \
# 1729         16.0  16  Intel Core i9 13th Gen.        NVIDIA GeForce RTX 4070
# ...

# %%
df['Price'].mean()
# Out:
# 517.5528048780487

# %%
df['Screen_Size'].mean()
# Out:
# 14.550237127371275

# %%
print(df.to_string())
# Out:
#           Brand                                                               Product_Description  Screen_Size    RAM                    Processor                                                 GPU                        GPU_Type                                  Resolution                Condition   Price
# 0        Lenovo   Lenovo ThinkPad 14” HD Laptop PC Computer Core i5 16GB RAM 256GB SSD Windows 10        14.00     16       Intel Core i5 7th Gen.                               Intel HD Graphics 520    Integrated/On-Board Graphics                                         NaN  Very Good - Refurbished  189.99
# 1          Dell    Dell Latitude 15.6" Laptop Intel Core i5 64GB RAM 2TB SSD Wi-Fi Windows 11 Pro        15.60     64       Intel Core i5 8th Gen.                              Intel UHD Graphics 620    Integrated/On-Board Graphics                                 1920 x 1080  Very Good - Refurbished  349.99
# ...

# %%
df['Screen_Size'].sort_values(ascending=True)
# Out:
# 1312    10.0
# 2618    10.1
# 74      10.1
# 180     10.1
# 2841    10.5
#         ...
# 2060    17.3
# 2791    17.3
# 1084    17.3
# 1432    17.3
# 1391    18.0
# Name: Screen_Size, Length: 2952, dtype: float64

# %%
df["Brand"].sort_values(ascending=True)
# Out:
# 1562      AVITA
# 2189       Acer
# 406        Acer
# 2809       Acer
# 2448       Acer
#          ...
# 920     Samsung
# 1031    Samsung
# 1167       Sony
# 965        Sony
# 878        Sony
# Name: Brand, Length: 2952, dtype: object

# %%
df.shape
# Out:
# (2952, 10)

# %%
df.columns
# Out:
# Index(['Brand', 'Product_Description', 'Screen_Size', 'RAM', 'Processor',
#        'GPU', 'GPU_Type', 'Resolution', 'Condition', 'Price'],
#       dtype='object')

# %%
df.sort_values('Brand', ascending=True)
# Out:
#         Brand                                Product_Description  Screen_Size  \
# 1562    AVITA  AVITA Clarus 14 Laptop Win10 Intel Core i5 Pro...         14.0
# 2189     Acer  Acer Aspire 3 Intel Core i5-1035G1 8GB 256 GB ...         15.6
# 406      Acer  Acer Swift 3 Thin & Light Laptop, 14" FHD IPS,...         14.0
# 2809     Acer  NEW Acer Swift 3 SF314-55-58P9 14" Notebook - ...         14.0
# 2448     Acer  New Acer 13.5" Swift 3 Laptop IPS LCD Core i7-...         13.5
# ...       ...                                                ...          ...
# 920   Samsung  SAMSUNG 13.3" Galaxy Chromebook 256GB 8GB, 4K ...         13.3
# 1031  Samsung  New Samsung Galaxy Book3 Ultra 16'' 3K AMOLED ...         16.0
# 1167     Sony  NEW Sony VAIO VWNC51429-BK Laptop 14.1" FHD 16...         14.1
# 965      Sony  Sony Vaio Laptop 14.1" IPS FHD Intel i5-1235U ...         14.1
# 878      Sony  VAIO VWNC51427-BK 14.1'' (512GB SSD, Intel Cor...         14.1
#
# ...

# %%
df.sort_values('Price', ascending=True)
# Out:
#          Brand                                Product_Description  \
# 1729     Razer  Razer Blade 16" (1TB SSD, Intel Core i9 13th G...
# 1369      Dell  Dell XPS 15 9530 15.6" (1TB SSD, Intel Core i9...
# 2287        HP  HP Envy x360 15-ed0003ca 15.6" (1TB SSD, Intel...
# 948       Dell  Dell Latitude Rugged 7330 32GB I7 512GB 4G LTE...
# 2698      Dell  2021 Dell Latitude 7320 Detachable i7-1180G7 1...
# ...        ...                                                ...
# 2668  Gigabyte  Aorus 13.9" X3 Plus v5 Intel Core i7 6700HQ (2...
# 2247      Dell  Dell Latitude 7430 i7-1265U 2TB PCIe 16GB FHD ...
# 220     Lenovo  Lenovo ThinkPad X1 Carbon Gen 11 14 2023 FHD+ ...
# 2454      Dell  Dell Precision 7550 Laptop i7-10875H 512GB PCI...
# 2313      Dell  Dell Gaming G15 5510 15.6" 512GB SSD Core i7-1...
#
#       Screen_Size RAM                Processor                            GPU  \
# 1729         16.0  16  Intel Core i9 13th Gen.        NVIDIA GeForce RTX 4070
# ...

# %%
df.sort_values("Screen_Size", ascending=True).head()
# Out:
#           Brand                                Product_Description  \
# 1312  Panasonic  Panasonic Toughbook CF-20 MK2 • Premium KB • i...
# 2618     Ruggon  RuggOn Rextorm PX501 10.1” Intel i5 8th GEN 8G...
# 74    Panasonic  Panasonic Toughbook CF-20 MK2 i5 16gb 256gb Du...
# 180   Panasonic  Panasonic CF-20 mk2 i5-7Y57 16gb 256gb SSD New...
# 2841  Microsoft  Microsoft 8VC-00001 Surface Go 3 10.5" Intel i...
#
#       Screen_Size RAM                Processor                     GPU  \
# 1312         10.0  16   Intel Core i5 7th Gen.                     NaN
# 2618         10.1   8   Intel Core i5 8th Gen.                     NaN
# 74           10.1  16   Intel Core i5 7th Gen.   Intel HD Graphics 615
# 180          10.1  16   Intel Core i5 7th Gen.   Intel HD Graphics 615
# 2841         10.5   8  Intel Core i3 10th Gen.  Intel UHD Graphics 615
#
#                           GPU_Type   Resolution                Condition  \
# ...

# %%
Mean1 = df["Price"].mean()
Mean1
# Out:
# 517.5528048780487

# %%
df[df['Price']>=Mean1].head()
# Out:
#      Brand                                Product_Description  Screen_Size  \
# 6   Lenovo  Lenovo V15 G4 IRU 15.6" Full HD Laptop, i7-135...         15.6
# 11    Dell  New Dell Latitude 5440 256GB SSD, Intel Core i...         14.0
# 13    Asus  ASUS ROG Flow Z13 120Hz FHD+ i7 RTX 3050 16GB ...         13.4
# 17    Asus  ASUS 15.6" Q530VJ- I73050 512GB SSD Intel Core...         15.6
# 37    Asus  ASUS TUF Dash F15 Gaming Laptop (Core i7 12650...         15.6
#
#    RAM                Processor                      GPU  \
# 6   16  Intel Core i7 13th Gen.   Intel Iris Xe Graphics
# 11  16  Intel Core i5 13th Gen.   Intel Iris Xe Graphics
# 13  16  Intel Core i7 12th Gen.  NVIDIA GeForce RTX 3050
# 17  16  Intel Core i7 13th Gen.  NVIDIA GeForce RTX 3050
# 37  16  Intel Core i7 12th Gen.  NVIDIA GeForce RTX 3060
#
#                         GPU_Type   Resolution                Condition   Price
# 6   Integrated/On-Board Graphics  1920 x 1080                 Open box  529.98
# ...

# %%
df[df['Price'] <= Mean1]
# Out:
#        Brand                                Product_Description  Screen_Size  \
# 0     Lenovo  Lenovo ThinkPad 14” HD Laptop PC Computer Core...         14.0
# 1       Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...         15.6
# 2         HP  NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...         15.6
# 3     Lenovo  2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...         15.6
# 4     Lenovo  2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...         15.6
# ...      ...                                                ...          ...
# 2940  Lenovo  NEW Lenovo 21JK0052US ThinkPad E14 Gen 5 14" T...         14.0
# 2942      HP  HARMONY Gelish VITAGEL Nail Strengthener LED /...         14.0
# 2943  Lenovo  NEW Lenovo 82XF001TUS IdeaPad Slim 5 16IRL8 16...         16.0
# 2950      HP  HP 15 Laptop 15.6" FHD i5-1135G7 8GB RAM 256GB...         15.6
# 2951      HP  3 PCS Karlash 6 Column Undated Appointment Boo...         14.0
#
# ...

# %%
df.describe()
# Out:
#        Screen_Size        Price
# count  2952.000000  2952.000000
# mean     14.550237   517.552805
# std       1.175322   235.592872
# min      10.000000     0.000000
# 25%      14.000000   325.990000
# 50%      14.000000   489.990000
# 75%      15.600000   699.000000
# max      18.000000   999.990000

# %%
df.isnull()
# Out:
#       Brand  Product_Description  Screen_Size    RAM  Processor    GPU  \
# 0     False                False        False  False      False  False
# 1     False                False        False  False      False  False
# 2     False                False        False  False      False  False
# 3     False                False        False  False      False  False
# 4     False                False        False  False      False  False
# ...     ...                  ...          ...    ...        ...    ...
# 2947  False                False        False  False      False  False
# 2948  False                False        False  False      False  False
# 2949  False                False        False  False      False  False
# 2950  False                False        False  False      False  False
# 2951  False                False        False  False      False  False
#
#       GPU_Type  Resolution  Condition  Price
# 0        False        True      False  False
# ...

# %%
df[df.isnull()].count()
# Out:
# Brand                  0
# Product_Description    0
# Screen_Size            0
# RAM                    0
# Processor              0
# GPU                    0
# GPU_Type               0
# Resolution             0
# Condition              0
# Price                  0
# dtype: int64

# %%
df.loc[0]
# Out:
# Brand                                                             Lenovo
# Product_Description    Lenovo ThinkPad 14” HD Laptop PC Computer Core...
# Screen_Size                                                         14.0
# RAM                                                                   16
# Processor                                         Intel Core i5 7th Gen.
# GPU                                                Intel HD Graphics 520
# GPU_Type                                    Integrated/On-Board Graphics
# Resolution                                                           NaN
# Condition                                        Very Good - Refurbished
# Price                                                             189.99
# Name: 0, dtype: object

# %%
df.rename(columns={'Screen_Size':'Size_Of_Screen'}, inplace=True)
df.head()
# Out:
#     Brand                                Product_Description  Size_Of_Screen  \
# 0  Lenovo  Lenovo ThinkPad 14” HD Laptop PC Computer Core...            14.0
# 1    Dell  Dell Latitude 15.6" Laptop Intel Core i5 64GB ...            15.6
# 2      HP  NEW HP 15 Laptop. 15.6" 1080p, i5-1135G7, 8GB ...            15.6
# 3  Lenovo  2024 Lenovo Ideapad Laptop 15 FHD Touch Intel ...            15.6
# 4  Lenovo  2024 Lenovo Ideapad Laptop 15.6" FHD Touch Int...            15.6
#
#   RAM                Processor                     GPU  \
# 0  16   Intel Core i5 7th Gen.   Intel HD Graphics 520
# 1  64   Intel Core i5 8th Gen.  Intel UHD Graphics 620
# 2   8  Intel Core i5 11th Gen.  Intel Iris Xe Graphics
# 3  Up  Intel Core i5 11th Gen.  Intel Iris Xe Graphics
# 4  16  Intel Core i5 11th Gen.  Intel Iris Xe Graphics
#
#                        GPU_Type   Resolution                Condition   Price
# 0  Integrated/On-Board Graphics          NaN  Very Good - Refurbished  189.99
# ...
