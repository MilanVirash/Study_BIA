# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.arange(2.5, 200.5, 10)
# Out:
# array([  2.5,  12.5,  22.5,  32.5,  42.5,  52.5,  62.5,  72.5,  82.5,
#         92.5, 102.5, 112.5, 122.5, 132.5, 142.5, 152.5, 162.5, 172.5,
#        182.5, 192.5])

# %%
x = np.arange(0, 20)
y = np.arange(11, 31)

# %%
plt.scatter(x, y, c="#75E849")
plt.xlabel("Hight")
plt.ylabel("Weight")
# Out:
# Text(0, 0.5, 'Weight')

# %%
plt.plot(x, y, "m*")

# %%
plt.plot(x, y, "g*", linestyle = '--')

# %%
plt.plot?
# Out:
# Signature:
# plt.plot(
#     *args: 'float | ArrayLike | str',
#     scalex: 'bool' = True,
#     scaley: 'bool' = True,
#     data=None,
#     **kwargs,
# ) -> 'list[Line2D]'
# Docstring:
# Plot y versus x as lines and/or markers.
#
# Call signatures::
#
#     plot([x], y, [fmt], *, data=None, **kwargs)
#     plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
# The coordinates of the points or line nodes are given by *x*, *y*.
#
# The optional parameter *fmt* is a convenient way for defining basic
# formatting like color, marker and linestyle. It's a shortcut string
# notation described in the *Notes* section below.
#
# >>> plot(x, y)        # plot x and y using default line style and color
# >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
# >>> plot(y)           # plot y using x as index array 0..N-1
# >>> plot(y, 'r+')     # ditto, but with red plusses
#
# You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
import pandas as pd
df = pd.read_csv('drinks.csv')
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
plt.plot(df["beer_servings"], df["wine_servings"], "y*", linestyle = "--", linewidth = 1, markersize = 15, mec = "r", mfc = "b")
plt.xlabel("Beer Servings")
plt.ylabel("Wine Servings")
# Out:
# Text(0, 0.5, 'Wine Servings')

# %%
plt.scatter(df["beer_servings"], df["wine_servings"])

# %%
plt.bar(df["continent"], df["wine_servings"])
plt.xlabel("Continent")
plt.ylabel("wine_servings")
plt.title("")
# Out:
# Text(0, 0.5, 'wine_servings')

# %%
plt.figure(figsize=(15, 10))
#plt.figure(figsize=(width, height))


plt.subplot(2, 2, 1)
plt.plot(df["country"], df["beer_servings"], "r-")
plt.xlabel("Country")
plt.ylabel("beer_servings")

plt.subplot(2, 2, 2)
plt.plot(df["continent"], df["wine_servings"], "y")
plt.xlabel("continent")
plt.ylabel("wine_servings")

plt.subplot(2, 2, 3)
plt.scatter(df["spirit_servings"], df["wine_servings"], c="g")
plt.xlabel("spirit_servings")
plt.ylabel("wine_servings")

plt.subplot(2, 2, 4)
plt.bar(df["total_litres_of_pure_alcohol"], df["continent"], )
plt.xlabel("total_litres_of_pure_alcohol")
plt.ylabel("continent")
# Out:
# Text(0, 0.5, 'continent')

# %%
import matplotlib.pyplot as plt

# Adjust the size of the entire figure
plt.figure(figsize=(12, 8))

# First subplot
plt.subplot(2, 2, 1)
plt.plot(df["country"], df["beer_servings"], "r-")
plt.xlabel("Country")
plt.ylabel("beer_servings")

# Second subplot
plt.subplot(2, 2, 2)
plt.plot(df["continent"], df["wine_servings"], "y")
plt.xlabel("continent")
plt.ylabel("wine_servings")

# Third subplot
plt.subplot(2, 2, 3)
plt.scatter(df["spirit_servings"], df["wine_servings"], c="g")
plt.xlabel("spirit_servings")
plt.ylabel("wine_servings")

# Fourth subplot
plt.subplot(2, 2, 4)
plt.bar(df["total_litres_of_pure_alcohol"], df["continent"])
plt.xlabel("total_litres_of_pure_alcohol")
plt.ylabel("continent")

# Display the plot
plt.tight_layout()
plt.show()

# %%
plt.bar(df["continent"], df["beer_servings"], color = "#A09C9B")
plt.xlabel("Continent")
plt.ylabel("beer_servings")
# Out:
# Text(0, 0.5, 'beer_servings')

# %%
plt.bar(df["country"], df["beer_servings"], color = "maroon")
plt.xlabel("Continent")
plt.ylabel("beer_servings")
# Out:
# Text(0, 0.5, 'beer_servings')

# %%
df["beer_servings"].sort_values(ascending=True)
# Out:
# 0        0
# 40       0
# 79       0
# 90       0
# 97       0
#       ...
# 135    343
# 65     346
# 62     347
# 45     361
# 117    376
# Name: beer_servings, Length: 193, dtype: int64

# %%
df2 = df.sort_values("beer_servings", ascending=False).head(5)
df2
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 98        Lithuania            343              244             56
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8    Africa
# 45                           11.8    Europe
# 62                            8.9    Africa
# 65                           11.3    Europe
# 98                           12.9    Europe

# %%
plt.bar(df2["country"], df2["beer_servings"], color = "#BFD641", width = 0.5, )
plt.xlabel("Country")
plt.ylabel("Beer Serving")
plt.title("Country wise Beer Serving")
# Out:
# Text(0.5, 1.0, 'Country wise Beer Serving')

# %%
plt.bar(df2["country"], df2["beer_servings"], color = "black", width=0.5)
plt.scatter(df2["country"], df2["wine_servings"], color = "Red")
plt.xlabel("Country")
plt.ylabel("Beer Serving & wine_servings")
plt.title("Country wise Beer Serving & wine_servings")
# Out:
# Text(0.5, 1.0, 'Country wise Beer Serving & wine_servings')

# %%
a = np.array([1, 25, 36, 58, 8, 56, 63, 85, 96, 74, 25, 36, 38, 40, 15])
plt.hist(a, bins=10)
plt.xlabel("a")
plt.ylabel("Counts")
# Out:
# Text(0, 0.5, 'Counts')

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df3 = df.drop(["country", "continent"], axis=1, inplace=False)

# %%
plt.boxplot(df3)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x155f3533310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x155f3533850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x155f3533070>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x155f3533d90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x155f3548070>,
# ...
#  'means': []}

# %%
plt.boxplot(df3["total_litres_of_pure_alcohol"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x155f35b9990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x155f35b9ed0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x155f35b96f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x155f35ba410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x155f35ba6b0>],
#  'means': []}

# %%
counts = [400, 340, 200]
plt.pie(counts, labels=["SG", "CG", "MN"], colors=['gold', 'yellowgreen', 'lightcoral'], explode=(0.1, 0.1, 0.1))
# Out:
# ([<matplotlib.patches.Wedge at 0x155f3707970>,
# ...
#  [Text(0.27818414776612305, 1.167310404276273, 'SG'),
#   Text(-0.9417592519639368, -0.7436998798845716, 'CG'),
#   Text(0.9417592519639368, -0.7436998798845716, 'MN')])
