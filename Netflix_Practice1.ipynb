# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("netflix.csv")

df
# Out:
#                                                  title               genre  \
# 0                                     Notes for My Son               Drama
# 1                                     To Each, Her Own     Romantic comedy
# 2                                        The Lovebirds     Romantic comedy
# 3                                       The Perfection     Horror-thriller
# 4                                    Happy Anniversary     Romantic comedy
# ..                                                 ...                 ...
# 578  Rolling Thunder Revue: A bob Dylan Story by Ma...         Documentary
# 579                           Freaks: You're One of Us  Supernatural drama
# 580                                       Squared Love     Romantic comedy
# 581                                         My Own Man         Documentary
# 582                      Biggie: I Got a Story to Tell         Documentary
#
#     language  imdb_score    premiere  runtime  year
# ...

# %%
df.head()
# Out:
#                title            genre language  imdb_score    premiere  \
# 0   Notes for My Son            Drama  Spanish         6.3  11/24/2020
# 1   To Each, Her Own  Romantic comedy   French         5.3   6/24/2018
# 2      The Lovebirds  Romantic comedy  English         6.1   5/22/2020
# 3     The Perfection  Horror-thriller  English         6.1   5/24/2019
# 4  Happy Anniversary  Romantic comedy  English         5.8   3/30/2018
#
#    runtime  year
# 0       83  2020
# 1       95  2018
# 2       87  2020
# 3       90  2019
# 4       78  2018

# %%
df.tail()
# Out:
#                                                  title               genre  \
# 578  Rolling Thunder Revue: A bob Dylan Story by Ma...         Documentary
# 579                           Freaks: You're One of Us  Supernatural drama
# 580                                       Squared Love     Romantic comedy
# 581                                         My Own Man         Documentary
# 582                      Biggie: I Got a Story to Tell         Documentary
#
#     language  imdb_score    premiere  runtime  year
# 578  English         7.6   6/12/2019      144  2019
# 579   German         5.4    9/2/2020       92  2020
# 580   Polish         5.0   2/11/2021      102  2021
# 581  English         6.4  12/13/2014       81  2014
# 582  English         6.9    3/1/2021       97  2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   title       583 non-null    object
#  1   genre       583 non-null    object
#  2   language    583 non-null    object
#  3   imdb_score  583 non-null    float64
#  4   premiere    583 non-null    object
#  5   runtime     583 non-null    int64
#  6   year        583 non-null    int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 32.0+ KB

# %%
new_df = df.dropna()    # Dropma() function deal with empty cells is to remove rows that contain empty cells.

# %%
new_df.head()
# Out:
#                title            genre language  imdb_score    premiere  \
# 0   Notes for My Son            Drama  Spanish         6.3  11/24/2020
# 1   To Each, Her Own  Romantic comedy   French         5.3   6/24/2018
# 2      The Lovebirds  Romantic comedy  English         6.1   5/22/2020
# 3     The Perfection  Horror-thriller  English         6.1   5/24/2019
# 4  Happy Anniversary  Romantic comedy  English         5.8   3/30/2018
#
#    runtime  year
# 0       83  2020
# 1       95  2018
# 2       87  2020
# 3       90  2019
# 4       78  2018

# %%
df.dropna(inplace=True)     # By default, the dropna() method returns a new DataFrame, and will not change the original.
# If you want to change the original DataFrame, use the inplace = True argument:

#Now, the dropna(inplace = True) will NOT return a new DataFrame, but it will remove all rows containing NULL values from the original DataFrame.

# %%
df.head()
# Out:
#                title            genre language  imdb_score    premiere  \
# 0   Notes for My Son            Drama  Spanish         6.3  11/24/2020
# 1   To Each, Her Own  Romantic comedy   French         5.3   6/24/2018
# 2      The Lovebirds  Romantic comedy  English         6.1   5/22/2020
# 3     The Perfection  Horror-thriller  English         6.1   5/24/2019
# 4  Happy Anniversary  Romantic comedy  English         5.8   3/30/2018
#
#    runtime  year
# 0       83  2020
# 1       95  2018
# 2       87  2020
# 3       90  2019
# 4       78  2018

# %%
# Another way of dealing with empty cells is to insert a new value instead.
# This way you do not have to delete entire rows just because of some empty cells.
# The fillna() method allows us to replace empty cells with a value:

df.fillna(1, inplace=True)    #Replace NULL values with the number 130:
df.head()
# Out:
#                title            genre language  imdb_score    premiere  \
# 0   Notes for My Son            Drama  Spanish         6.3  11/24/2020
# 1   To Each, Her Own  Romantic comedy   French         5.3   6/24/2018
# 2      The Lovebirds  Romantic comedy  English         6.1   5/22/2020
# 3     The Perfection  Horror-thriller  English         6.1   5/24/2019
# 4  Happy Anniversary  Romantic comedy  English         5.8   3/30/2018
#
#    runtime  year
# 0       83  2020
# 1       95  2018
# 2       87  2020
# 3       90  2019
# 4       78  2018

# %% [markdown]
# # Data of Wrong Format

# %%
# Cells with data of wrong format can make it difficult, or even impossible, to analyze data.
# To fix it, you have two options: remove the rows, or convert all cells in the columns into the same format.

# %%
# Convert Into a Correct Format
#In our Data Frame, we have two cells with the wrong format. Check out row 22 and 26, the 'Date' column should be a string that represents a date:

# %%
df.describe()
# Out:
#        imdb_score     runtime         year
# count  583.000000  583.000000   583.000000
# mean     6.275129   93.490566  2018.934820
# std      0.976678   27.706665     1.474598
# min      2.500000    4.000000  2014.000000
# 25%      5.700000   86.000000  2018.000000
# 50%      6.400000   97.000000  2019.000000
# 75%      7.000000  107.500000  2020.000000
# max      9.000000  209.000000  2021.000000

# %%
df.sample()
# Out:
#                      title        genre language  imdb_score  premiere  \
# 175  Anelka: Misunderstood  Documentary   French         6.4  8/5/2020
#
#      runtime  year
# 175       94  2020

# %%
df['genre'].nunique()
# Out:
# 114

# %%
df['runtime'].nunique()
# Out:
# 124

# %%
df.iloc[124]
# Out:
# title            The Angel
# genre         Spy thriller
# language           English
# imdb_score             6.6
# premiere         9/14/2018
# runtime                114
# year                  2018
# Name: 124, dtype: object

# %%
df.iloc[114]
# Out:
# title                          Seventeen
# genre         Coming-of-age comedy-drama
# language                         Spanish
# imdb_score                           7.2
# premiere                      10/18/2019
# runtime                               99
# year                                2019
# Name: 114, dtype: object

# %%
df.columns
# Out:
# Index(['title', 'genre', 'language', 'imdb_score', 'premiere', 'runtime',
#        'year'],
#       dtype='object')

# %%
# loc() and iloc() methods are used in slicing data from the pandas DataFrames which hepls in filtering the data according to some given condition.

# loc()  ---> Select by Labels
# iloc() ---> Select by Positions

# %%
df.loc[2:5,['genre', 'imdb_score']]
# Out:
#              genre  imdb_score
# 2  Romantic comedy         6.1
# 3  Horror-thriller         6.1
# 4  Romantic comedy         5.8
# 5      Documentary         5.6

# %%
df.loc[(df.runtime > 100)]
# Out:
#                                                  title  \
# 15                                               Polar
# 17                                   In the Tall Grass
# 18                                   Pieces of a Woman
# 21                                  Our Souls at Night
# 23                                 Christmas Crossfire
# ..                                                 ...
# 572                                      Thunder Force
# 573                                           The King
# 574                           The Christmas Chronicles
# 578  Rolling Thunder Revue: A bob Dylan Story by Ma...
# 580                                       Squared Love
#
#                                   genre language  imdb_score    premiere  \
# 15                               Action  English         6.3   1/25/2019
# 17                               Horror  English         5.4   10/4/2019
# 18                                Drama  English         7.1    1/7/2021
# ...

# %%
df.loc[(df.genre == 'Action')]
# Out:
#                title   genre language  imdb_score    premiere  runtime  year
# 15             Polar  Action  English         6.3   1/25/2019      118  2019
# 42        Sentinelle  Action   French         4.7    3/5/2021       80  2021
# 282            Drive  Action    Hindi         3.5   11/1/2019      147  2019
# 370       Extraction  Action  English         6.7   4/24/2020      117  2020
# 399  Earth and Blood  Action   French         4.9   4/17/2020       80  2020
# 482    6 Underground  Action  English         6.1  12/13/2019      128  2019
# 495      Point Blank  Action  English         5.7   7/12/2019       86  2019

# %%
df.loc[(df.year == 2019)]
# Out:
#                                                  title             genre  \
# 3                                       The Perfection   Horror-thriller
# 7                     Brene Brown: The Call to Courage       Documentary
# 9    The Lonely Island Presents: The Unauthorized B...  Comedy / Musical
# 10    Porta dos Fundos: The First Temptation of Christ            Comedy
# 11                             El Pepe: A Supreme Life       Documentary
# ..                                                 ...               ...
# 570                                           Good Sam             Drama
# 573                                           The King  Historical drama
# 576        The Road to El Camino: A Breaking Bad Movie         Making-of
# 577                                          Paddleton      Drama-Comedy
# 578  Rolling Thunder Revue: A bob Dylan Story by Ma...       Documentary
#
#        language  imdb_score    premiere  runtime  year
# ...

# %%
df.loc[(df.language == 'Portuguese')]
# Out:
#                                                 title            genre  \
# 10   Porta dos Fundos: The First Temptation of Christ           Comedy
# 46                                         The Killer          Western
# 84                                       Get the Goat           Comedy
# 125                                     Get the Grift           Comedy
# 127               Porta dos Fundos: The Last Hangover           Comedy
# 221                            Just Another Christmas           Comedy
# 262                                         Laerte-se      Documentary
# 268         Emicida: AmarElo - It's All For Yesterday      Documentary
# 276                                      Rich in Love  Romantic comedy
# 356                                        Double Dad     Comedy-drama
# 509                             The Edge of Democracy      Documentary
# 531                                     Airplane Mode           Comedy
#
# ...

# %%
df.loc[(df.imdb_score == 6.0)]
# Out:
#                                       title                     genre  \
# 27                     Forgive Us Our Debts                     Drama
# 59                      The Princess Switch           Romantic comedy
# 121                                    iBoy  Science fiction/Thriller
# 162                       The Kissing Booth           Romantic comedy
# 192  To All the Boys: P.S. I Still Love You           Romantic comedy
# 238                          Murder Mystery            Comedy mystery
# 375                                 Juanita                     Drama
# 450      The Christmas Chronicles: Part Two          Christmas comedy
# 481                                 Rebecca         Romantic thriller
# 484                           Project Power                 Superhero
# 490                             Come Sunday                    Biopic
# 494                             War Machine                War-Comedy
# ...

# %%
df.loc[(df.language == 'Hindi')].head()
# Out:
#                title            genre language  imdb_score    premiere  \
# 60      House Arrest           Comedy    Hindi         5.5  11/15/2019
# 61        Yeh Ballet            Drama    Hindi         7.6   2/21/2020
# 69  Ginny Weds Sunny  Romantic comedy    Hindi         5.7   10/9/2020
# 76        Chopsticks           Comedy    Hindi         6.5   5/31/2019
# 89           Bulbbul           Horror    Hindi         6.6   6/24/2020
#
#     runtime  year
# 60      104  2019
# 61      117  2020
# 69      125  2020
# 76      100  2019
# 89       94  2020

# %%
df.loc[(df.genre == 'Comedy-drama')]
# Out:
#                                          title         genre    language  \
# 40                              The Polka King  Comedy-drama     English
# 47                                   Tall Girl  Comedy-drama     English
# 116                             The Laundromat  Comedy-drama     English
# 117  The Meyerowitz Stories (New and Selected)  Comedy-drama     English
# 147                                   Tallulah  Comedy-drama     English
# 161                               Rajma Chawal  Comedy-drama       Hindi
# 165                                     15-Aug  Comedy-drama     Marathi
# 230                 The Fundamentals of Caring  Comedy-drama     English
# 234                         Nappily Ever After  Comedy-drama     English
# 313                        The Heartbreak Club  Comedy-drama  Indonesian
# 336                     Crazy Awesome Teachers  Comedy-drama  Indonesian
# 356                                 Double Dad  Comedy-drama  Portuguese
# ...

# %%
df.loc[(df.language == 'Indonesian')]
# Out:
#                           title            genre    language  imdb_score  \
# 132                 June & Kopi            Drama  Indonesian         6.3
# 242                     Whipped  Romantic comedy  Indonesian         4.1
# 290      The Night Comes for Us  Action-thriller  Indonesian         7.0
# 313         The Heartbreak Club     Comedy-drama  Indonesian         6.4
# 321                Layla Majnun   Romantic drama  Indonesian         6.4
# 336      Crazy Awesome Teachers     Comedy-drama  Indonesian         6.2
# 354                  Geez & Ann   Romantic drama  Indonesian         5.1
# 550        Tersanjung the Movie            Drama  Indonesian         6.1
# 559  Love Like the Falling Rain            Drama  Indonesian         5.0
#
#        premiere  runtime  year
# 132   1/28/2021       90  2021
# 242   9/18/2020       97  2020
# 290  10/19/2018      121  2018
# 313   1/14/2021      101  2021
# 321   2/11/2021      119  2021
# 336   8/17/2020      101  2020
# ...

# %%
df.loc[(df.language == 'Spanish')].head()
# Out:
#                        title            genre language  imdb_score  \
# 0           Notes for My Son            Drama  Spanish         6.3
# 11   El Pepe: A Supreme Life      Documentary  Spanish         7.1
# 29           Crazy About Her  Romantic comedy  Spanish         6.6
# 31  Parchis: The Documentary      Documentary  Spanish         6.7
# 57             The Paramedic         Thriller  Spanish         5.6
#
#       premiere  runtime  year
# 0   11/24/2020       83  2020
# 11  12/27/2019       73  2019
# 29   2/26/2021      102  2021
# 31   7/10/2019      106  2019
# 57   9/16/2020       94  2020

# %%
df.loc[(df.genre == 'Thriller')].head()
# Out:
#                         title     genre language  imdb_score   premiere  \
# 23        Christmas Crossfire  Thriller   German         4.8  12/4/2020
# 28                   Clinical  Thriller  English         5.1  1/13/2017
# 33             I Am All Girls  Thriller  English         5.8  5/14/2021
# 35  In the Shadow of the Moon  Thriller  English         6.2  9/27/2019
# 38           Secret Obsession  Thriller  English         4.4  7/18/2019
#
#     runtime  year
# 23      106  2020
# 28      104  2017
# 33      107  2021
# 35      115  2019
# 38       97  2019

# %%
df[(df.title == 'Mercy')]
# Out:
#      title     genre language  imdb_score    premiere  runtime  year
# 529  Mercy  Thriller  English         4.2  11/22/2016       90  2016

# %%
df.iloc[:5, :3]     # Parameter[Rows, Columns]
# Out:
#                title            genre language
# 0   Notes for My Son            Drama  Spanish
# 1   To Each, Her Own  Romantic comedy   French
# 2      The Lovebirds  Romantic comedy  English
# 3     The Perfection  Horror-thriller  English
# 4  Happy Anniversary  Romantic comedy  English

# %%
df.loc[(df.runtime >= 100)]
# Out:
#                                                  title  \
# 15                                               Polar
# 17                                   In the Tall Grass
# 18                                   Pieces of a Woman
# 21                                  Our Souls at Night
# 23                                 Christmas Crossfire
# ..                                                 ...
# 572                                      Thunder Force
# 573                                           The King
# 574                           The Christmas Chronicles
# 578  Rolling Thunder Revue: A bob Dylan Story by Ma...
# 580                                       Squared Love
#
#                                   genre language  imdb_score    premiere  \
# 15                               Action  English         6.3   1/25/2019
# 17                               Horror  English         5.4   10/4/2019
# 18                                Drama  English         7.1    1/7/2021
# ...

# %%
df[['title', 'genre', 'language', 'imdb_score']].sort_values(by= 'imdb_score')
# Out:
#                                           title                  genre  \
# 409                             Enter the Anime            Documentary
# 544                                 Dark Forces               Thriller
# 288                                     The App  Science fiction/Drama
# 304                              The Open House        Horror thriller
# 246                                 Kaali Khuhi                Mystery
# ..                                          ...                    ...
# 410  Ben Platt: Live from Radio City Music Hall           Concert Film
# 515       Taylor Swift: Reputation Stadium Tour           Concert Film
# 72                      Springsteen on Broadway           One-man show
# 268   Emicida: AmarElo - It's All For Yesterday            Documentary
# 285    David Attenborough: A Life on Our Planet            Documentary
#
#              language  imdb_score
# 409  English/Japanese         2.5
# 544           Spanish         2.6
# ...

# %%
df.nsmallest(5, 'imdb_score')
# Out:
#                title                  genre          language  imdb_score  \
# 409  Enter the Anime            Documentary  English/Japanese         2.5
# 288          The App  Science fiction/Drama           Italian         2.6
# 544      Dark Forces               Thriller           Spanish         2.6
# 304   The Open House        Horror thriller           English         3.2
# 246      Kaali Khuhi                Mystery             Hindi         3.4
#
#        premiere  runtime  year
# 409    8/5/2019       58  2019
# 288  12/26/2019       79  2019
# 544   8/21/2020       81  2020
# 304   1/19/2018       94  2018
# 246  10/30/2020       90  2020

# %%
df.nlargest(5, 'imdb_score')
# Out:
#                                            title         genre  \
# 285     David Attenborough: A Life on Our Planet   Documentary
# 268    Emicida: AmarElo - It's All For Yesterday   Documentary
# 72                       Springsteen on Broadway  One-man show
# 214  Winter on Fire: Ukraine's Fight for Freedom   Documentary
# 410   Ben Platt: Live from Radio City Music Hall  Concert Film
#
#                      language  imdb_score    premiere  runtime  year
# 285                   English         9.0   10/4/2020       83  2020
# 268                Portuguese         8.6   12/8/2020       89  2020
# 72                    English         8.5  12/16/2018      153  2018
# 214  English/Ukranian/Russian         8.4   10/9/2015       91  2015
# 410                   English         8.4   5/20/2020       85  2020

# %%
df.groupby('runtime').agg(np.max)
# Out:
# C:\Users\milan\AppData\Local\Temp\ipykernel_18052\1320571921.py:1: FutureWarning: The provided callable <function max at 0x00000225CEFAD750> is currently using DataFrameGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby('runtime').agg(np.max)
#                                                      title  \
# runtime
# 4                                              Sol Levante
# 7                                         Cops and Robbers
# 9                                                  Canvas
# 10       American Factory: A Conversation with the Obamas
# 11                                                   Zion
# ...                                                    ...
# 149                        The Last Days of American Crime
# 151                                     The Forest of Love
# 153                                Springsteen on Broadway
# ...

# %%
df.groupby('genre').get_group('Documentary')
# Out:
#                                                  title        genre  \
# 5                                 Why Did You Kill Me?  Documentary
# 7                     Brene Brown: The Call to Courage  Documentary
# 11                             El Pepe: A Supreme Life  Documentary
# 12                Sky Ladder: The Art of Cai Guo-Qiang  Documentary
# 13                                    Out of Many, One  Documentary
# ..                                                 ...          ...
# 569              American Murder: The Family Next Door  Documentary
# 575                                          Long Shot  Documentary
# 578  Rolling Thunder Revue: A bob Dylan Story by Ma...  Documentary
# 581                                         My Own Man  Documentary
# 582                      Biggie: I Got a Story to Tell  Documentary
#
#              language  imdb_score    premiere  runtime  year
# 5             English         5.6   4/14/2021       83  2021
# ...

# %%
df.groupby('language').get_group('English')
# Out:
#                                                  title            genre  \
# 2                                        The Lovebirds  Romantic comedy
# 3                                       The Perfection  Horror-thriller
# 4                                    Happy Anniversary  Romantic comedy
# 5                                 Why Did You Kill Me?      Documentary
# 6                                        Death to 2020           Comedy
# ..                                                 ...              ...
# 576        The Road to El Camino: A Breaking Bad Movie        Making-of
# 577                                          Paddleton     Drama-Comedy
# 578  Rolling Thunder Revue: A bob Dylan Story by Ma...      Documentary
# 581                                         My Own Man      Documentary
# 582                      Biggie: I Got a Story to Tell      Documentary
#
#     language  imdb_score    premiere  runtime  year
# ...

# %%
df.groupby('language').language.describe().head()
# Out:
#                count unique             top freq
# language
# Bengali            1      1         Bengali    1
# Dutch              3      1           Dutch    3
# English          401      1         English  401
# English/Akan       1      1    English/Akan    1
# English/Arabic     1      1  English/Arabic    1

# %%
df.groupby('runtime').runtime.describe()
# Out:
#          count   mean  std    min    25%    50%    75%    max
# runtime
# 4          1.0    4.0  NaN    4.0    4.0    4.0    4.0    4.0
# 7          1.0    7.0  NaN    7.0    7.0    7.0    7.0    7.0
# 9          1.0    9.0  NaN    9.0    9.0    9.0    9.0    9.0
# 10         1.0   10.0  NaN   10.0   10.0   10.0   10.0   10.0
# 11         1.0   11.0  NaN   11.0   11.0   11.0   11.0   11.0
# ...        ...    ...  ...    ...    ...    ...    ...    ...
# 149        3.0  149.0  0.0  149.0  149.0  149.0  149.0  149.0
# 151        2.0  151.0  0.0  151.0  151.0  151.0  151.0  151.0
# 153        1.0  153.0  NaN  153.0  153.0  153.0  153.0  153.0
# 155        1.0  155.0  NaN  155.0  155.0  155.0  155.0  155.0
# 209        1.0  209.0  NaN  209.0  209.0  209.0  209.0  209.0
#
# [124 rows x 8 columns]

# %%
df.query('3 < imdb_score < 5').head()
# Out:
#                                                title                    genre  \
# 10  Porta dos Fundos: The First Temptation of Christ                   Comedy
# 23                               Christmas Crossfire                 Thriller
# 38                                  Secret Obsession                 Thriller
# 42                                        Sentinelle                   Action
# 43                                           Paradox  Musical/Western/Fantasy
#
#       language  imdb_score   premiere  runtime  year
# 10  Portuguese         4.6  12/3/2019       46  2019
# 23      German         4.8  12/4/2020      106  2020
# 38     English         4.4  7/18/2019       97  2019
# 42      French         4.7   3/5/2021       80  2021
# 43     English         3.9  3/23/2018       73  2018

# %%
df.set_index('runtime').head()
# Out:
#                      title            genre language  imdb_score    premiere  \
# runtime
# 83        Notes for My Son            Drama  Spanish         6.3  11/24/2020
# 95        To Each, Her Own  Romantic comedy   French         5.3   6/24/2018
# 87           The Lovebirds  Romantic comedy  English         6.1   5/22/2020
# 90          The Perfection  Horror-thriller  English         6.1   5/24/2019
# 78       Happy Anniversary  Romantic comedy  English         5.8   3/30/2018
#
#          year
# runtime
# 83       2020
# 95       2018
# 87       2020
# 90       2019
# 78       2018

# %%
numerical_df = df.select_dtypes(include=np.number)
numerical_df.head()
# Out:
#    imdb_score  runtime  year
# 0         6.3       83  2020
# 1         5.3       95  2018
# 2         6.1       87  2020
# 3         6.1       90  2019
# 4         5.8       78  2018

# %%
categorical_df = df.select_dtypes(include=object)
categorical_df.head()
# Out:
#                title            genre language    premiere
# 0   Notes for My Son            Drama  Spanish  11/24/2020
# 1   To Each, Her Own  Romantic comedy   French   6/24/2018
# 2      The Lovebirds  Romantic comedy  English   5/22/2020
# 3     The Perfection  Horror-thriller  English   5/24/2019
# 4  Happy Anniversary  Romantic comedy  English   3/30/2018

# %%
comb_df = pd.concat([numerical_df, categorical_df], axis=1)
comb_df.head()
# Out:
#    imdb_score  runtime  year              title            genre language  \
# 0         6.3       83  2020   Notes for My Son            Drama  Spanish
# 1         5.3       95  2018   To Each, Her Own  Romantic comedy   French
# 2         6.1       87  2020      The Lovebirds  Romantic comedy  English
# 3         6.1       90  2019     The Perfection  Horror-thriller  English
# 4         5.8       78  2018  Happy Anniversary  Romantic comedy  English
#
#      premiere
# 0  11/24/2020
# 1   6/24/2018
# 2   5/22/2020
# 3   5/24/2019
# 4   3/30/2018

# %%
np.mean(df.imdb_score)
# Out:
# 6.275128644939965

# %%
np.average(df.imdb_score)
# Out:
# 6.275128644939965

# %%
np.sum(df.title == 'Notes for My Son')
# Out:
# 1

# %%
np.sum(df.genre == "Drama")
# Out:
# 77

# %%
np.sum(df.language == 'Spanish')
# Out:
# 31

# %%
np.sum(df.language == 'English')
# Out:
# 401

# %%
np.average(df.runtime)
# Out:
# 93.49056603773585

# %%
np.std(df.runtime)
# Out:
# 27.682892467318716

# %%
np.std(df.imdb_score)
# Out:
# 0.9758396704134903

# %%
df.isnull().sum()
# Out:
# title         0
# genre         0
# language      0
# imdb_score    0
# premiere      0
# runtime       0
# year          0
# dtype: int64

# %%
df['language'].value_counts()
# Out:
# language
# English                       401
# Hindi                          32
# Spanish                        31
# French                         20
# Italian                        14
# Portuguese                     12
# Indonesian                      9
# Korean                          6
# Japanese                        6
# English/Spanish                 5
# German                          5
# Turkish                         5
# Polish                          3
# Dutch                           3
# Marathi                         3
# Filipino                        2
# Thai                            2
# English/Japanese                2
# English/Hindi                   2
# English/Mandarin                2
# English/Korean                  1
# Khmer/English/French            1
# English/Akan                    1
# Bengali                         1
# English/Swedish                 1
# English/Arabic                  1
# English/Taiwanese/Mandarin      1
# ...

# %%
import matplotlib.pyplot as plt

# %%
df['imdb_score'].hist()
plt.xlabel('imdb_score')
plt.ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %%
plt.show()

# %%
df.boxplot(column='imdb_score')
# Out:
# <Axes: >

# %%
plt.scatter(df['runtime'], df['imdb_score'])
plt.xlabel('Runtime')
plt.ylabel('imdb_score')
# Out:
# Text(0, 0.5, 'imdb_score')

# %%
plt.bar(df.genre, df.language, color='y')
# Out:
# <BarContainer object of 583 artists>

# %%
plt.savefig('myplot.png')
